# %%
# Import Library
import pandas as pd
import numpy as np
import os

# %%
os.chdir('B:\Workstation\Dropbox\DataCenter\GHTK\GHTK_Reports\GHTKPython')
CODlist = pd.read_excel("CodQ1.xlsx")
CODlist

# Xoa dataframe: >del Dataset
# Out:
#           Cart                      Cod
# 0     SG17.22A    T3048-Trần Khắc Quyền
# 1     SG17.22A    T3358-Huỳnh Trung Tài
# 2     SG17.22A   T50182-Nguyễn Minh Tâm
# 3     SG17.22A      T84017-Phạm Lý Bình
# 4     SG17.22A   T108044-Nguyễn Hữu Tài
# ..         ...                      ...
# 116      CTVHT       T269709-Võ Phú Lộc
# 117  PARTIME T   T263826-Đinh Tuấn Kiệt
# 118      CTVHT  T269250-Phạm Trung Tuấn
# 119      CTVHT  T266355-Từ Duy Ngọc Bảo
# 120      CTVHT     T266658-Hồ Văn Thiện
#
# [121 rows x 2 columns]

# %%
CODlist["NoCOD"]='T' + CODlist['Cod'].str.extract('(\d+)')
CODlist
# Out:
#           Cart                      Cod    NoCOD
# 0     SG17.22A    T3048-Trần Khắc Quyền    T3048
# 1     SG17.22A    T3358-Huỳnh Trung Tài    T3358
# 2     SG17.22A   T50182-Nguyễn Minh Tâm   T50182
# 3     SG17.22A      T84017-Phạm Lý Bình   T84017
# 4     SG17.22A   T108044-Nguyễn Hữu Tài  T108044
# ..         ...                      ...      ...
# 116      CTVHT       T269709-Võ Phú Lộc  T269709
# 117  PARTIME T   T263826-Đinh Tuấn Kiệt  T263826
# 118      CTVHT  T269250-Phạm Trung Tuấn  T269250
# 119      CTVHT  T266355-Từ Duy Ngọc Bảo  T266355
# 120      CTVHT     T266658-Hồ Văn Thiện  T266658
#
# [121 rows x 3 columns]

# %%
CODlist.to_excel(r'CODlistQ1.xlsx')
